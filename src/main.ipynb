# %%
from settings.config import config

for key, value in config.items():
  print(f"キー: {key}")
  if isinstance(value, list):
    print('  User-agent: *')
    for item in value:
      print(f"  Disallow: {item}")
  else:
    print(f"  値: {value}")
# Out:
# キー: example.com
#   User-agent: *
#   Disallow: /_anlz/！
#   Disallow: /_assets/！
#   Disallow: /assets/！
#   Disallow: /assets_c/！
#   Disallow: /error/！
#   Disallow: /giftbox/！
# キー: a.example.com
#   User-agent: *
#   Disallow: /_anlz/！
#   Disallow: /_assets/！
# キー: example.net
#   User-agent: *
#   Disallow: /_anlz/！
